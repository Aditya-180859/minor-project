# %%
# Supress warning 
# for supress any warning
import warnings
warnings.filterwarnings('ignore')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\91707\\jupyter\\data science class'

# %%
#First Import the main modules
#iimport numpy for array or it's array operataion
import numpy as np 
#import pandas for the creating dataframes and it's operations
import pandas as pd
#import statistics for statistics function
import statistics as s
#import seaborn for data visualization 
import seaborn as sns
#import matplotlib for data visualization
import matplotlib.pyplot as plt

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Load the Admission Dataset into mydata

mydata = pd.read_csv("Admission_Predict.csv")
#here we use read_csv for reading the data set

# %%
mydata
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
#first we check top five of the dataset . Here we check our variables name
mydata.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
mydata.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 395         1             0.82
# 396         1             0.84
# 397         1             0.91
# 398         0             0.67
# 399         1             0.95

# %%
mydata.shape
# Out:
# (400, 9)

# %%
#here we check the datatpes 
mydata.dtypes
# Out:
# Serial No.             int64
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
#univariate analysis
mydata['GRE Score'].describe(include="all")
# Out:
# count    400.000000
# mean     316.807500
# std       11.473646
# min      290.000000
# 25%      308.000000
# 50%      317.000000
# 75%      325.000000
# max      340.000000
# Name: GRE Score, dtype: float64

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
# checking null values 
mydata.isnull().sum()
# There are no null values
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
mydata.describe().T
# Out:
#                    count        mean        std     min     25%     50%  \
# GRE Score          400.0  316.807500  11.473646  290.00  308.00  317.00
# TOEFL Score        400.0  107.410000   6.069514   92.00  103.00  107.00
# University Rating  400.0    3.087500   1.143728    1.00    2.00    3.00
# SOP                400.0    3.400000   1.006869    1.00    2.50    3.50
# LOR                400.0    3.452500   0.898478    1.00    3.00    3.50
# CGPA               400.0    8.598925   0.596317    6.80    8.17    8.61
# Research           400.0    0.547500   0.498362    0.00    0.00    1.00
# Chance of Admit    400.0    0.724350   0.142609    0.34    0.64    0.73
#
#                         75%     max
# GRE Score          325.0000  340.00
# TOEFL Score        112.0000  120.00
# University Rating    4.0000    5.00
# SOP                  4.0000    5.00
# LOR                  4.0000    5.00
# CGPA                 9.0625    9.92
# Research             1.0000    1.00
# ...

# %%
#there is no need of serial no so we drop it from the dataset
mydata = mydata.drop(columns="Serial No.")

# %%
#here we check the coorelation
corr = mydata.corr()

# %%
corr
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.835977           0.668976  0.612831
# TOEFL Score         0.835977     1.000000           0.695590  0.657981
# University Rating   0.668976     0.695590           1.000000  0.734523
# SOP                 0.612831     0.657981           0.734523  1.000000
# LOR                 0.557555     0.567721           0.660123  0.729593
# CGPA                0.833060     0.828417           0.746479  0.718144
# Research            0.580391     0.489858           0.447783  0.444029
# Chance of Admit     0.802610     0.791594           0.711250  0.675732
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          0.557555  0.833060  0.580391         0.802610
# TOEFL Score        0.567721  0.828417  0.489858         0.791594
# University Rating  0.660123  0.746479  0.447783         0.711250
# SOP                0.729593  0.718144  0.444029         0.675732
# ...

# %%
sns.heatmap(corr,cmap='YlGnBu', annot=True)

# %%
# Outlier Analysis
fig ,axs = plt.subplots(3, figsize=(5,5))
plt1 = sns.boxplot(mydata['CGPA'],ax=axs[0])
plt2 = sns.boxplot(mydata['GRE Score'],ax=axs[1])
plt3 = sns.boxplot(mydata['TOEFL Score'],ax=axs[2])
plt.tight_layout()

# %%
sns.boxplot(mydata['Chance of Admit'])

# %%
sns.boxplot(mydata['CGPA'])

# %%
sns.boxplot(mydata['GRE Score'])

# %%
sns.boxplot(mydata['TOEFL Score'])

# %%
# Let's see how Sales are related with other variables using scatter plot.
sns.pairplot(mydata,x_vars=['GRE Score','TOEFL Score','CGPA'],y_vars=['Chance of Admit'], height=4,aspect=1,kind='scatter')
plt.show()

# %%
sns.distplot(mydata['GRE Score'])
mydata['GRE Score'].describe()
# Out:
# count    400.000000
# mean     316.807500
# std       11.473646
# min      290.000000
# 25%      308.000000
# 50%      317.000000
# 75%      325.000000
# max      340.000000
# Name: GRE Score, dtype: float64

# %%
sns.distplot(mydata['TOEFL Score'])

# %%
sns.distplot(mydata['CGPA'])

# %%
attr = ["Chance of Admit","CGPA","GRE Score","TOEFL Score"]
pd.plotting.scatter_matrix(mydata[attr],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F5177CC608>,
# ...
#       dtype=object)

# %%
x0 = mydata[['GRE Score']]
x1 = mydata[['TOEFL Score']]
x2 = mydata[['CGPA']]
x3 = mydata[['SOP']]
y =  mydata[['Chance of Admit']]

# %%
#from linearregress import

# %%
class slr:
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def predict(self):
        #first import the important libraries
        import numpy as np
        import pandas as pd
        from sklearn.model_selection import train_test_split
        from sklearn.linear_model import LinearRegression
        from sklearn import metrics
        from sklearn.model_selection import cross_val_score
        #second split the data in training and testin
        X_train,X_test,y_train,y_test = train_test_split(self.x,self.y,test_size=0.4,random_state=0)
        reg = LinearRegression(normalize=True)
        print("################### Prediction ###################")
        #Third fit the model
        lin_reg = reg.fit(X_train,y_train)
        y_pred = reg.predict(X_test)
        y_train_pred = lin_reg.predict(X_train)
        print(X_test)
        print("---------")
        print(y_pred)
        
        print("###################Prediction Score ###################")
        mae = metrics.mean_absolute_error(X_test, y_pred)
        mse = metrics.mean_squared_error(X_test, y_pred)
        rmse = np.sqrt(metrics.mean_squared_error(X_test,y_pred))
        r2_square = metrics.r2_score(y_test, y_pred)
        print("################### MAE MSE RMSE ###################")
        print(f"MAE = {mae}, MSE = {mse}, RMSE = {rmse}, R2 = {r2_square}")
#         print(f"R2 = {r2_square}")
    def ypred(self,x):
        import numpy as np
        import pandas as pd
        from sklearn.model_selection import train_test_split
        from sklearn.linear_model import LinearRegression
        from sklearn import metrics
        from sklearn.model_selection import cross_val_score
        #second split the data in training and testin
        X_train,X_test,y_train,y_test = train_test_split(self.x,self.y,test_size=0.4,random_state=0)
        reg = LinearRegression(normalize=True)
        print("################### Prediction ###################")
        #Third fit the model
        lin_reg = LinearRegression(normalize=True)
        lin_reg.fit(X_train,y_train)
        y1_pred =lin_reg.predict([[x]])
        return y1_pred

# %%
obj = slr(x0,y)
obj.predict()
print("========")
gre_score = obj.ypred(338)
print(gre_score)
# Out:
# ################### Prediction ###################
#      GRE Score
# 132        309
# 309        308
# 341        326
# 196        306
# 246        316
# ..         ...
# 136        312
# 275        322
# 126        323
# 198        311
# 299        305
#
# [160 rows x 1 columns]
# ---------
# [[0.64515838]
#  [0.63481565]
#  [0.82098474]
#  [0.6141302 ]
#  [0.71755747]
#  [0.64515838]
#  [0.67618656]
#  [0.67618656]
#  [0.8830411 ]
#  [0.87269837]
#  [0.55207384]
#  [0.89338383]
#  [0.75892838]
#  [0.57275929]
#  [0.84167019]
#  [0.66584384]
#  [0.67618656]
#  [0.85201292]
#  [0.70721474]
#  [0.68652929]
#  [0.85201292]
#  [0.83132747]
#  [0.56241657]
#  [0.5003602 ]
#  [0.75892838]
#  [0.56241657]
#  [0.51070293]
#  [0.69687202]
#  [0.92441201]
#  [0.69687202]
#  [0.67618656]
#  [0.78995656]
#  [0.67618656]
#  [0.51070293]
#  [0.81064201]
#  [0.83132747]
#  [0.73824292]
#  [0.78995656]
#  [0.62447293]
#  [0.89338383]
#  [0.77961383]
#  [0.69687202]
#  [0.7692711 ]
#  [0.80029929]
# ...

# %%
obj = slr(x1,y)
obj.predict()
toefl_score = obj.ypred(118)
print(toefl_score)
# Out:
# ################### Prediction ###################
#      TOEFL Score
# 132          105
# 309          110
# 341          110
# 196          105
# 246          105
# ..           ...
# 136          103
# 275          110
# 126          113
# 198          104
# 299          112
#
# [160 rows x 1 columns]
# ---------
# [[0.67953961]
#  [0.77428999]
#  [0.77428999]
#  [0.67953961]
#  [0.67953961]
#  [0.58478923]
#  [0.75533991]
#  [0.66058954]
#  [0.9258906 ]
#  [0.90694052]
#  [0.67953961]
#  [0.83114022]
#  [0.77428999]
#  [0.56583916]
#  [0.81219014]
#  [0.66058954]
#  [0.54688908]
#  [0.77428999]
#  [0.56583916]
#  [0.71743976]
#  [0.94484067]
#  [0.83114022]
#  [0.69848969]
#  [0.50898893]
#  [0.79324007]
#  [0.58478923]
#  [0.49003885]
#  [0.67953961]
#  [0.9258906 ]
#  [0.69848969]
#  [0.60373931]
#  [0.71743976]
#  [0.71743976]
#  [0.56583916]
#  [0.81219014]
#  [0.81219014]
#  [0.69848969]
#  [0.83114022]
#  [0.62268938]
#  [0.90694052]
#  [0.71743976]
#  [0.71743976]
# ...

# %%
obj = slr(x2,y)
print(obj.predict())
cgpa_score = obj.ypred(8)
print(cgpa_score)
# Out:
# ################### Prediction ###################
#      CGPA
# 132  8.56
# 309  8.60
# 341  8.76
# 196  8.26
# 246  8.73
# ..    ...
# 136  8.45
# 275  8.96
# 126  9.32
# 198  8.43
# 299  8.65
#
# [160 rows x 1 columns]
# ---------
# [[0.71497228]
#  [0.72346597]
#  [0.75744071]
#  [0.65126964]
#  [0.75107044]
#  [0.61729489]
#  [0.74257676]
#  [0.61517147]
#  [0.88484599]
#  [0.89758652]
#  [0.55359225]
#  [0.86785862]
#  [0.71497228]
#  [0.43680407]
#  [0.82963704]
#  [0.65976332]
#  [0.63428227]
#  [0.84025414]
#  [0.57270304]
#  [0.74257676]
#  [0.84237757]
#  [0.83813072]
#  [0.69586149]
#  [0.45591487]
#  [0.78079834]
#  [0.60455437]
#  [0.4983833 ]
#  [0.65976332]
#  [0.84874783]
#  [0.64914622]
#  [0.60455437]
#  [0.71284886]
#  [0.73408307]
#  [0.60243094]
#  [0.79141545]
#  [0.74894702]
#  [0.57907331]
#  [0.85724152]
#  [0.65339306]
#  [0.94854864]
#  [0.69373807]
#  [0.65339306]
#  [0.63852911]
#  [0.78079834]
#  [0.83176046]
#  [0.59606068]
#  [0.52174093]
# ...

# %%
obj = slr(x3,y)
obj.predict()
sop_score = obj.ypred(4)
print(sop_score)
# Out:
# ################### Prediction ###################
#      SOP
# 132  3.5
# 309  3.5
# 341  3.5
# 196  3.0
# 246  3.0
# ..   ...
# 136  5.0
# 275  3.5
# 126  4.0
# 198  4.5
# 299  3.0
#
# [160 rows x 1 columns]
# ---------
# [[0.73178148]
#  [0.73178148]
#  [0.73178148]
#  [0.68270848]
#  [0.68270848]
#  [0.68270848]
#  [0.68270848]
#  [0.73178148]
#  [0.82992748]
#  [0.82992748]
#  [0.48641648]
#  [0.78085448]
#  [0.78085448]
#  [0.58456248]
#  [0.78085448]
#  [0.58456248]
#  [0.73178148]
#  [0.78085448]
#  [0.73178148]
#  [0.78085448]
#  [0.82992748]
#  [0.82992748]
#  [0.63363548]
#  [0.53548948]
#  [0.82992748]
#  [0.73178148]
#  [0.68270848]
#  [0.73178148]
#  [0.82992748]
#  [0.78085448]
#  [0.63363548]
#  [0.73178148]
#  [0.82992748]
#  [0.63363548]
#  [0.73178148]
#  [0.68270848]
#  [0.78085448]
#  [0.78085448]
#  [0.68270848]
#  [0.87900048]
#  [0.73178148]
#  [0.63363548]
#  [0.68270848]
#  [0.78085448]
#  [0.78085448]
#  [0.68270848]
#  [0.58456248]
#  [0.78085448]
# ...

# %%
#final result
final_result = (gre_score+toefl_score+cgpa_score+sop_score)/4*100
print(f"The final result is {final_result}")
# Out:
# The final result is [[81.19758047]]

# %%
if(final_result>=70):
    print("you are eligible for addmission")
else:
    print("you are not eligible for addmission")
# Out:
# you are eligible for addmission

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\91707\jupyter\data science class
